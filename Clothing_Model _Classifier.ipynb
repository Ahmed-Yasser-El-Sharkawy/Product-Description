# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import shutil

# Define source and destination paths
source_path = '/content/drive/MyDrive/data/Final Project /Data.zip'
destination_path = '/content/Data.zip'

# Copy the file
shutil.copy(source_path, destination_path)

print(f'File copied from {source_path} to {destination_path}')
# Out:
# File copied from /content/drive/MyDrive/data/Final Project /Data.zip to /content/Data.zip

# %%
# !unzip '/content/Data.zip'
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Mobile-Phones/Samsung/1638064507831_Samsung Galaxy M21 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639531631924_Samsung Galaxy S9 64GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636400144518_Samsung Galaxy A50 4GB 64GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636620837963_Samsung Galaxy S20FE 128GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636615987614_Samsung Galaxy J1 Nxt Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638060537529_Samsung Galaxy A10s Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638392677016_Samsung Galaxy S8 64GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639537047435_Samsung Galaxy A03s 464 New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636628296851_Samsung Galaxy A51 128GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635054024017_Samsung Galaxy J7 SMJ700F Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636617326830_Samsung Galaxy J6 4gb 64gb Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636614677057_Samsung Galaxy J2 G532DS Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639529605347_Samsung Galaxy S9 128GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635133410577_Samsung Galaxy A12 New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639529537200_Samsung Galaxy J7 2016 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636614356193_Samsung Galaxy M32 New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636622332740_Samsung Galaxy M21 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638399359235_Samsung Galaxy A11 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638067701170_Samsung Galaxy J7 J 7pro Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635061186185_Samsung Galaxy S7 Edge Gold Platinum Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638393812343_Samsung Galaxy S7 Edge 32GB Ful Set Box New New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638398208455_Samsung Galaxy Note 20 Ultra 5G  12GB 256GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636401840937_Samsung Galaxy J2 16GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636405286064_Samsung Galaxy S20 128GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636626549620_Samsung Galaxy M21 6gb 128gb Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638064254050_Samsung Galaxy A12 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639529039687_Samsung Galaxy S9 664GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638396760896_Samsung Galaxy A12 64GB ROM  4GB RAM New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638058919504_Samsung Galaxy A20s A20s32gb Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638070386624_Samsung Galaxy M01 Core 2GB32GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638060566779_Samsung Galaxy S8 64GB FUL SET IME BOX New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639534909333_Samsung Galaxy Note 10 5G Auro Black Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639530356018_Samsung Galaxy S9 64GB 4GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638398017712_Samsung Galaxy J4 3GB32GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636405353209_Samsung Galaxy M02 3GB 32GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635054334677_Samsung Galaxy Note 10 Plus 2019 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638392941062_Samsung Galaxy J2 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639528654476_Samsung Galaxy A50 4GB 64GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638060533547_Samsung Galaxy M32 8GB RAM New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638396189658_Samsung Galaxy Note 10 Plus Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638067548726_Samsung Galaxy J4 2GB 32GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636404964989_Samsung Galaxy Fold 2 5G  12GB 256GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638395805574_Samsung Wide2 2Gb Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639529461701_Samsung Galaxy A10s Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638070227526_Samsung Galaxy S21 Ultra 12GB256GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638393595280_Samsung Galaxy A03s New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638399553789_Samsung Galaxy Y Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636410642326_Samsung Galaxy A11 2GB 32GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639531997971_Samsung Galaxy M01 Black Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638060159899_Samsung Galaxy A52 8GB RAM New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636402297063_Samsung Galaxy J7 Prime Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638058891433_Samsung Galaxy Note 20 Ultra 256Gb Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636622972628_Samsung Galaxy M20 3GB 32GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638059453553_Samsung Galaxy A12 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636621859968_Samsung Galaxy A2 Core Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638065634267_Samsung Galaxy Note 2 32gb Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638393378731_Samsung Galaxy A71 8GB 128GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636409221901_Samsung Galaxy A51 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638396969638_Samsung Galaxy M02 2gb32gb Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636400144972_Samsung Galaxy M11 3GB 32GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638397629319_Samsung Galaxy A2 Core Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635150446759_Samsung Galaxy A50 S  Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639536077420_Samsung Galaxy M02s 64GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635061645259_Samsung Galaxy J2 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638391097814_Samsung Galaxy A03s 3GB 32GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638065161475_Samsung J5 Prime Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638391444342_Samsung Galaxy S20FE 1288GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635060926206_Samsung Galaxy Note 8 64GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638057741054_Samsung Galaxy A71 128GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635132996253_Samsung Galaxy M51 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638058919813_Samsung Galaxy Z Flip 5G  256GB 8GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635061469750_Samsung Galaxy M02s Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636399568356_Samsung Galaxy M52 8Gb New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638062612555_Samsung Galaxy A50 64GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638068235829_Samsung Galaxy S3 4G Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638060157503_Samsung Galaxy A71 8GB RAM New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635054514712_Samsung Galaxy Note 9 128GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638063532111_Samsung Galaxy M32 8GB RAM  128GB ROM New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638068232406_Samsung Galaxy Z Fold3 12GB 256GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639540246625_Samsung Galaxy S8 64GB Black Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636402797032_Samsung Galaxy J1 use phone Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635133032149_Samsung Pocket GTS5301 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636406035235_Samsung Galaxy J1 Ace Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638392968957_Samsung Galaxy J7 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638065633722_Samsung Galaxy A10 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638394509929_Samsung Galaxy A7 64GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636407845945_Samsung Galaxy J7 Prime Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635151377938_Samsung Galaxy S9 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639530190864_Samsung Galaxy M02 2GB32GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636402991519_Samsung Galaxy S3 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638059873355_Samsung Galaxy Note 2 32GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638392021020_Samsung Galaxy A32 128GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636623031480_Samsung Galaxy S20FE 5G 8GB 128GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639541295086_Samsung Galaxy M22 6128GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635063582088_Samsung Galaxy M21 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639534758562_Samsung Galaxy M02s Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635058900700_Samsung Galaxy Note 8 6GB 64GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635133000787_Samsung Galaxy A03s 4Gb 64Gb Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636627854707_Samsung Galaxy M12 6128GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636628329122_Samsung Galaxy Y Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638395404902_Samsung Galaxy A12 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635064843970_Samsung Galaxy J1 Next Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636404808449_Samsung Galaxy A03s 3GB 32GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639535541603_Samsung Galaxy Note 10 5G 256GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639535719858_Samsung Galaxy A72 New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636618465557_Samsung Galaxy A30 S used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639530659116_Samsung Galaxy A52s 2021 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636623692226_Samsung Galaxy S10 used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639536045643_Samsung Galaxy A6 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636618207493_Samsung Galaxy S9 4GB 64GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638391707743_Samsung Galaxy S6 Edge 3gbram 32gb rom Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639529987210_Samsung Galaxy J5 Prime Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635053125191_Samsung Galaxy S7 4GB 32GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638395125565_Samsung Galaxy Note 20 Ultra 12GB256GB 5G Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638069817230_Samsung Galaxy A32 New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638396233912_Samsung Galaxy A52 8GB RAM 128GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639537895270_Samsung Galaxy M32 8gB 128GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636616461738_Samsung Galaxy M02s Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638062480180_Samsung Galaxy A9 SMG887N Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636616321492_Samsung Galaxy Z Fold3 256GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639529138539_Samsung Galaxy A5 A510 2GB Ram Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638057806580_Samsung Galaxy A72 8GB l Blue New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636619476776_Samsung Galaxy J6 2020 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638395334418_Samsung Galaxy Note 9 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638062769089_Samsung Galaxy A03s 4GB 64GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639532677997_Samsung Galaxy S8 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636400853723_Samsung Galaxy Note 8 6GB 64GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639529683197_Samsung Galaxy J7 wide 2 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635142597166_Samsung Galaxy M02 2GB32GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635061507797_Samsung Galaxy M32 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639531066313_Samsung Galaxy J6 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639533117040_Samsung Galaxy S20 128GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638063664234_Samsung Galaxy M02s  Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638396473675_Samsung Galaxy M11 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639532443358_Samsung Galaxy J2 Pro 2GB Ram Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639532877548_Samsung Galaxy S20 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635068708164_Samsung Galaxy M32 8GB 128GB Black New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638394153022_Samsung Galaxy S10 128GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639537370614_Samsung Galaxy A32 128GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635149449574_Samsung SMB310E Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635059702397_Samsung Galaxy A20s 3GB 32GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636408422765_Samsung Galaxy A30 464GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638063192627_Samsung Galaxy M12 6GB RAM  128GB ROM New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636404864008_Samsung Galaxy A30 S Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636409009091_Samsung Galaxy A5 2GB 16GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639532844910_Samsung Galaxy J7 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638064407498_Samsung Galaxy S7 Edge Black Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635053124151_Samsung Galaxy A32 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636620445635_Samsung Galaxy M02s 32GB Dual Sim Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636628618669_Samsung Galaxy A03s 3GB RAM  32GB ROM New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638395944350_Samsung J7 Pro Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638057505397_Samsung Galaxy A10 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636620261716_Samsung Galaxy A2 Core Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636626118859_Samsung A90 5G Snapdragon Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639533612832_Samsung Galaxy J7 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638066833998_Samsung Galaxy M21 464 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636619885047_Samsung Galaxy M20 4GB 64GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638064279370_Samsung Galaxy S6 Edge 4GB 32GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636404397854_Samsung Galaxy M32 8GB RAM  128GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639535129266_Samsung Galaxy Note 10 Plus 12GB 128GB DUALSIM Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636625091829_Samsung Galaxy A12 4GB l 64GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639537338024_Samsung Galaxy Y duos Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636405950245_Samsung A82 5G 6GB 128GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638399035829_Samsung Galaxy J6 3GB 32GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636401686435_Samsung Galaxy A20s Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636617801474_Samsung Galaxy A20 3GB32GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635069583108_Samsung Galaxy J4 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636615019105_Samsung Galaxy S8 4GB64GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639539491545_Samsung Galaxy S7 Max Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638391390024_Samsung Galaxy A12 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638057708882_Samsung Galaxy M12 6GB 128GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635054785706_Samsung Galaxy M11 332 New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639538087759_Samsung Galaxy Note 9 128GB FULL SET BOX New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638394375577_Samsung Galaxy A20 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635052652685_Samsung Galaxy Note Edge Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639531149122_Samsung Galaxy S9 6GB RAM  256GB ROM Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636624192723_Samsung Galaxy S10 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636402964998_Samsung Galaxy A20 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635149902084_Samsung Galaxy J2 Prime Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635068668482_Samsung Galaxy A51 New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635133166911_Samsung Galaxy A30 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639534531941_Samsung Galaxy A71 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638060670779_Samsung Galaxy Note 8 64GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636627725888_Samsung Galaxy M12 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636404456271_Samsung Galaxy S5 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636401758197_Samsung Galaxy A10s 32GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635062404885_Samsung Galaxy M10 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638065531753_Samsung Galaxy J3 J320 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635140245659_Samsung Galaxy A51 Black Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639535995670_Samsung Galaxy S8 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638395919478_Samsung Galaxy A11 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638069182581_Samsung Galaxy A22 4G Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638396969939_Samsung Galaxy A6 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638057949795_Samsung Galaxy A90 5G 128GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636405738441_Samsung Galaxy J7 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638395941643_Samsung Galaxy A21s Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638057920993_Samsung Galaxy M01 Core New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638396850458_Samsung Galaxy M01 Core Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638393348529_Samsung Galaxy A2 Core 1gb 16gb Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639530073765_Samsung Galaxy S10 Blue Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636614221415_Samsung Galaxy S20 Ultra Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639537895960_Samsung Galaxy M02 2GB 32GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635149028490_Samsung Galaxy S21 Ultra 256GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639532553487_Samsung Galaxy A70 128GB 6GB RAM Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636615241143_Samsung Galaxy A51  128GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636399995139_Samsung Galaxy Note 10 Plus 256GB  512GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639540098192_Samsung Galaxy Note 20 Ultra 256GB FULL SET BOX New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636406612648_Samsung Galaxy Note 9 512GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638069109720_Samsung Galaxy M02 New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635143954926_Samsung Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635069907796_Samsung Galaxy J1 Nxt Prime Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636623065291_Samsung F42 5G 8GB 128GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636408524030_Samsung Galaxy J7 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638060188000_Samsung Galaxy S10 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638068764584_Samsung Galaxy J7 Prime Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638068123048_Samsung Galaxy M20 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636624516039_Samsung Galaxy S9 s9h Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638398569887_Samsung Galaxy A21s 64GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638063487226_Samsung Galaxy S10e 128GB PRISM BLUE Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636625993610_Samsung Galaxy S9 64GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636621901144_Samsung F42 5G 8GB 128GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639530097943_Samsung Galaxy J7 J7pro 2018 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635054709729_Samsung Galaxy A72 8128 New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638393508788_Samsung Galaxy S21 Plus Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636401810108_Samsung Galaxy J1 4GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636629173381_Samsung Galaxy A72 8128 New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638399499797_Samsung Galaxy F42 8GB 128GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636401051922_Samsung Galaxy A20s 3GB 32GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636402827144_Samsung Galaxy A03s New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639530193566_Samsung Galaxy M01 Core 2GB 32GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638394865258_Samsung Galaxy M32 5G New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636616779317_Samsung Galaxy M02s 64GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635132086472_Samsung Galaxy J7 Max Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638390307874_Samsung Galaxy M01 Core Black 32GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638397072383_Samsung Galaxy J7 used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639538006664_Samsung Galaxy A20 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636615621589_Samsung Galaxy Nexus Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636408521323_Samsung Galaxy S21 Ultra Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639529899300_Samsung Galaxy A10 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639528848784_Samsung Galaxy M32 used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635064597521_Samsung Galaxy A11 2020 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639537686046_Samsung Galaxy M02 32GB 3GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639536621320_Samsung Galaxy A11 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638392470533_Samsung Galaxy M12 2021 New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638393734564_Samsung Galaxy A03s 64 Gb 4 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636406766109_Samsung Galaxy S10 Plus Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636624306532_Samsung Galaxy Grand Max Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639530958683_Samsung Galaxy J5 And J1 2016 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638069261109_Samsung Galaxy S20FE 1288GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635054479756_Samsung Galaxy Note 10 Lite 128GB  8GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639536955882_Samsung Galaxy A21s Black 3GBRam 48MP Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636619716524_Samsung Galaxy J7 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638393412593_Samsung Galaxy A03s 4GB RAM  64GB ROM New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636401328396_Samsung B310 New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638398492825_Samsung Galaxy M02 232 New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636402565117_Samsung Galaxy A03s 3GB 32GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636400332015_Samsung Galaxy S21 256GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638067308865_Samsung Galaxy S10 Plus Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638392557422_Samsung Galaxy A20s 3GB32GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638059181434_Samsung Galaxy J7 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638395505154_Samsung Galaxy S10 128GB FULL SET 100 New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638069151279_Samsung Galaxy S6 32 Gb Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635151305011_Samsung Galaxy M01 Core 2GB 32GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636408680648_Samsung B110 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635053312844_Samsung Galaxy Note 4 8GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638397404387_Samsung Galaxy A8 Black Edition Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639530764821_Samsung Galaxy A12 New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636624822480_Samsung Galaxy A21s 64GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638395833741_Samsung Galaxy Core Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636409006353_Samsung Galaxy A30 4 64GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636409164238_Samsung Galaxy A30 S 2021 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638395314239_Samsung Galaxy J6 J6 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638066162640_Samsung Galaxy A03s 64GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636620833595_Samsung Galaxy Note 8 6GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636405545715_Samsung Galaxy M01 Core Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638057950044_Samsung Galaxy M02 2GB Ram  32 Rom New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638060923621_Samsung Galaxy A80 128GB  Gold Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639532734069_Samsung Galaxy A03s 332GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638061767170_Samsung Galaxy A71 8GB RAM Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638058888136_Samsung Galaxy Note 8 64GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636619144030_Samsung Galaxy J4 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638064777153_Samsung Galaxy Note 20 Ultra 12GB RAM New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636619201597_Samsung Galaxy S10 Plus 8GB128GBDUAL SIM Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636624360870_Samsung Galaxy J2 Pro 2016 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636402801036_Samsung Galaxy S10 8GB  128GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635063616967_Samsung Galaxy M21 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635062939914_Samsung Galaxy M12 6GB 128GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639541956594_Samsung Galaxy A03s New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639533151645_Samsung Galaxy S8 s8plus Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636399662184_Samsung Galaxy A7 4G Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639532304831_Samsung Galaxy A12 4128 New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638397242063_Samsung Galaxy M02 232GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636618775578_Samsung Galaxy J7 Prime Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638065387275_Samsung Galaxy A12 New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639535924458_Samsung Galaxy J7 3GB32GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636623972195_Samsung B110 New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638070196520_Samsung Galaxy A03s 4GB64GB Blue New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638067169651_Samsung Galaxy S9 128GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638069879391_Samsung Galaxy A80 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636404754588_Samsung Galaxy M02 3GB 32GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638059898656_Samsung Galaxy M01 Core Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635068709036_Samsung Galaxy S10 5G  256GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638389881113_Samsung Galaxy M32 5G New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636622750758_Samsung Galaxy M02 3GB 32GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635053036251_Samsung Galaxy M01 Core Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638393252624_Samsung Galaxy M02s 4 GB 64 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636403156275_Samsung Galaxy Note 8 6GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639540286834_Samsung Galaxy M42 8GB128GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638393760465_Samsung Galaxy J7 next Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638059306929_Samsung Galaxy A21s  Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635150813258_Samsung Galaxy J7 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636617999087_Samsung Galaxy S10 Plus 128GB FULL SET 100 New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638060536723_Samsung Galaxy M32 5G 8GB 128GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639539021190_Samsung Galaxy Note 10 Plus 256GB 12GB DUALSIM Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636624727719_Samsung Galaxy A11 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636408798123_Samsung Galaxy A32 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638389980994_Samsung Galaxy A50 Black Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636625050565_Samsung Galaxy S Dous 2 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638399472898_Samsung Galaxy A20 32GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636401688540_Samsung Galaxy J4 4G Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638396064242_Samsung Galaxy A52s 5G 128GB 8GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635150360056_Samsung Galaxy J7 Prime 3GB RAM Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636400240469_Samsung Galaxy J8 4GB64GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636404643285_Samsung GALAXY M22 128GB 6GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638396091810_Samsung Galaxy Grand Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639539995092_Samsung Galaxy J7 Prime Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639533668516_Samsung Galaxy Note 9 128GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635064061363_Samsung Galaxy A10s Dual sim Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636401512183_Samsung Galaxy A12 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639535544339_Samsung Galaxy A11 232GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639531965232_Samsung Galaxy A9 Pro 128GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638064560571_Samsung Galaxy A12 2021 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636403726366_Samsung Galaxy M01 Core 232GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639538604782_Samsung Galaxy M21 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636621896663_Samsung Galaxy Z Fold3 12GB 256GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635059806681_Samsung Galaxy Wide 3 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635150270529_Samsung Galaxy Alpha 3GB 32GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635132968450_Samsung Galaxy A12 64GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638398381490_Samsung Galaxy A80 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638058491551_Samsung Galaxy M01 Core 16GB Sealed New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638395066694_Samsung Galaxy M02 3GB RAM 32GB MEMORY New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636626927227_Samsung Galaxy J7 Pro 32GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638395041578_Samsung Galaxy A12 4GB RAM  128GB ROM New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635061356107_Samsung Galaxy S10 Plus 5G  256GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636405788290_Samsung Galaxy Note 4 4G 32GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636404588265_Samsung Galaxy M42 8GB  128GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635060628049_Samsung Galaxy M12 4GB64GB Company New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636400857880_Samsung Galaxy A7 Good condition Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635150299933_Samsung Galaxy J7 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639538945284_Samsung Galaxy M12 4GB 64GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636616464305_Samsung B310 New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639533540817_Samsung Galaxy J1 Ace Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635149939320_Samsung Galaxy A21s 48MP 5000mAh White New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639541603469_Samsung Galaxy A50 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636407668451_Samsung Galaxy A21s Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638058671683_Samsung Galaxy M22 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638061832671_Samsung Galaxy J7 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636627887979_Samsung Galaxy A6 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636628328744_Samsung Galaxy M32 128GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636407050945_Samsung Galaxy M32 New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639533611508_Samsung Galaxy A52 128GB 8GB Black New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636404045754_Samsung Galaxy A03s 4GB RAM 64GB ROM New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638058864230_Samsung Galaxy Note 20 5G Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636399936655_Samsung Galaxy M02s 64GB4GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636616015194_Samsung Galaxy M21 4GB 64GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636402382607_Samsung Galaxy A21s Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636625023324_Samsung Galaxy A21s 6GB 128GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639538506163_Samsung Galaxy A71 5G Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635058898737_Samsung Galaxy A10s Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639531834030_Samsung Galaxy A51 6GB 128GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638391781484_Samsung Galaxy A03s 3GB32GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638059741282_Samsung SMB310E Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635058750490_Samsung M42 5G New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638068438925_Samsung Galaxy J2 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636405571762_Samsung Galaxy M01 phone Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638063804692_Samsung Galaxy M10 2gb16gb Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638395944019_Samsung Galaxy A20 32GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636402644038_Samsung Galaxy Note 10 12GB 256GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636622722677_Samsung Galaxy M02s 4GB 64GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636407349228_Samsung Galaxy A50 4GB RAM  64GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638391495416_Samsung Galaxy M31 12GB Rom 6Gb Ram Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638397629558_Samsung Galaxy J7 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639539524315_Samsung Galaxy M12 6GB128GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639531998137_Samsung Galaxy S10 Plus 8GB 128GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635053067383_Samsung Galaxy M02 3GB 32GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636619103828_Samsung Galaxy M10 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636407343673_Samsung Galaxy Note 10 Plus 256GB  512GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639534754361_Samsung Galaxy A12 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639530896260_Samsung Galaxy A03s 64GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638057837186_Samsung Galaxy A52 128gb 8gb Ram Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638395313591_Samsung Galaxy A21s New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635061634400_Samsung Galaxy M10 used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638066099404_Samsung Galaxy A30 S Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638064377808_Samsung Galaxy M30 64GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638390008095_Samsung Galaxy A30 SCV43 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635053737323_Samsung Galaxy M02s 4GB 64GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638396728205_Samsung Galaxy M32 8GB RAM 128GB ROM New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636403642644_Samsung Galaxy M01 Core 1GB16GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636402733581_Samsung Galaxy S9 6GB RAM Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635064768679_Samsung Galaxy M01 Core 202116Gb New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639541645859_Samsung Galaxy S10 Plus 5G 256GB 8GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638394220952_Samsung Galaxy M02s Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636406246119_Samsung Galaxy A12 4GB 64GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636405712429_Samsung Core Prime Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635149595086_Samsung Galaxy M12 6GB Ram128GB memory New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638058317982_Samsung Galaxy M32 5G New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638399667481_Samsung Galaxy S10 Plus Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638398591382_Samsung Galaxy S10 Plus 128GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635064873250_Samsung Galaxy M32 8GB 128GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638066100933_Samsung Galaxy J Feel 32GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636616833751_Samsung Galaxy M02 3GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636405403658_Samsung Galaxy J7 Duos 432GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638065326249_Samsung Galaxy A50 64GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638393094994_Samsung Galaxy S20 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636625222254_Samsung Galaxy A20 3GB 32GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636405980772_Samsung Galaxy M02s Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636408252446_Samsung Galaxy S9 64GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638069576590_Samsung Galaxy J7 Pro 32GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635133341846_Samsung Galaxy M32 8GB 128GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636404810470_Samsung Galaxy A7 2018 4GB64GB Blue Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638059454047_Samsung Galaxy S10 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638065599037_Samsung Galaxy M02 32GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636621543435_Samsung Galaxy M31 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636407743159_Samsung Galaxy A10 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636618146480_Samsung Galaxy J2 1GB 8GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635068920322_Samsung Galaxy M01 Core 2021 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636409670475_Samsung Galaxy M21s Blue Edition Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636409840451_Samsung Galaxy M12 Black New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636404455221_Samsung Galaxy Note 20 Ultra 12GB RAM 256GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635053203024_Samsung Galaxy A10 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636404157527_Samsung Galaxy A50 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638393129020_Samsung Galaxy Note 20 Ultra 5G  256GB 12GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638068407630_Samsung Galaxy M02s Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639540851300_Samsung Galaxy A80 8gb128gb Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636400909483_Samsung Galaxy S9 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636404995050_Samsung Feel 4G32GB3GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635132787032_Samsung Galaxy J2 8GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639532846637_Samsung Galaxy S Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638396352276_Samsung Galaxy A10s Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636407430579_Samsung Galaxy A32 New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638397569917_Samsung Galaxy A71 128GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638061835541_Samsung Galaxy Note 8 128GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636408739875_Samsung Galaxy A80 128GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638397988035_Samsung Galaxy A72 8GB256GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636615307725_Samsung Galaxy A12 4GB64GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638058862968_Samsung Galaxy M02 3gb 32g New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639534357802_Samsung Galaxy Note 4 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636621386136_Samsung Galaxy A12 464GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635061497599_Samsung Galaxy S10 Plus Prism White Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639537176770_Samsung Galaxy S20FE 5G 128GB Green Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636404047759_Samsung Galaxy J5 4g Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635059104777_Samsung Galaxy A03s 4GB 64GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638396292676_Samsung Galaxy J2 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638067944645_Samsung Galaxy J2  Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635052361168_Samsung GT190601 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635054097570_Samsung Galaxy S10 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638395531648_Samsung Galaxy S9 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636627307338_Samsung Galaxy S10 Plus 128GB8GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635064025744_Samsung Galaxy A10 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638399176877_Samsung Galaxy Note 1 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638060825492_Samsung Galaxy A12 4GB128GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638398957937_Samsung Galaxy J5 2015 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636406492383_Samsung Galaxy M10 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636614677905_Samsung Galaxy S10 Plus international 512GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636622660512_Samsung Galaxy J6 32GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639534946501_Samsung Galaxy A03s Ram 4 GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638400269887_Samsung Galaxy A32 8GB128GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635055414479_Samsung Galaxy A10 32GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636402297496_Samsung Galaxy A50 S Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638060371285_Samsung Galaxy M21 6GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635142087281_Samsung Galaxy M20 2019 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636402019219_Samsung Galaxy S10 Plus 8GB 128GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638397712369_Samsung Galaxy A32 New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638068531398_Samsung Galaxy S21 Ultra 5G 256GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638062258596_Samsung Galaxy Z Flip3 8128GB BLACK New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639530475168_Samsung Galaxy A03s 4GB RAM  64GB ROM New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639539247393_Samsung Galaxy A72 8128GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638067582048_Samsung Galaxy A03s New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638067553389_Samsung Galaxy A51 6GB128GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639529605793_Samsung Galaxy A72 8GB 128GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638058414967_Samsung Galaxy J6 Gold Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638069380110_Samsung Galaxy M02 32GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636406765038_Samsung Galaxy M32 8GB128GB BLU New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639541371178_Samsung Galaxy A03s 64GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636399780399_Samsung Galaxy M02s Brand new Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636614151646_Samsung Galaxy M02 2GB 32GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636627052393_Samsung Galaxy M32 8GB128GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635151119442_Samsung Galaxy A8 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638061245696_Samsung Galaxy A21s 2021 6gb Ram 128gb New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635149096667_Samsung Galaxy M21 4Gb Ram Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636628181662_Samsung Galaxy M01 M1 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636627795595_Samsung Galaxy S8 64GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639529802104_Samsung Galaxy S10 Plus 5G 256GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1635053834844_Samsung Galaxy M02 2GB32GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638060498623_Samsung Galaxy M12 6GB 128GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639541325810_Samsung Galaxy J6 SMJ610F Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636615381011_Samsung Galaxy M21 64gb Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636622660744_Samsung Galaxy M02 3GB 32GB New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638398811914_Samsung Galaxy M02s Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639540707227_Samsung Galaxy Note 5 4GB Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636404775631_Samsung Galaxy M01 Core Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636409895909_Samsung Galaxy J5 super Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638398813017_Samsung Galaxy J4 J4 Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1639531502632_Samsung Galaxy S10 New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636405738287_Samsung Galaxy A03s 3GB RAM  32GB ROM New for sale.jpg
#   inflating: Mobile-Phones/Samsung/1638060730518_Samsung Galaxy A32 A03 S Used for sale.jpg
#   inflating: Mobile-Phones/Samsung/1636627575208_Samsung Galaxy J7 Prime 2 Used for sale.jpg
# ...
#   inflating: Clothing/T-Shirt/Image_248.jpg
#   inflating: Clothing/T-Shirt/Image_510.jpg
#   inflating: Clothing/T-Shirt/Image_500.jpeg
#   inflating: Clothing/T-Shirt/Image_414.jpg
#   inflating: Clothing/T-Shirt/Image_922.png
#   inflating: Clothing/T-Shirt/Image_7.jpg
#   inflating: Clothing/T-Shirt/Image_806.jpg
#   inflating: Clothing/T-Shirt/Image_822.jpeg
#   inflating: Clothing/T-Shirt/Image_892.png
#   inflating: Clothing/T-Shirt/Image_404.jpg
#   inflating: Clothing/T-Shirt/Image_264.jpg
#   inflating: Clothing/T-Shirt/Image_153.jpeg
#   inflating: Clothing/T-Shirt/Image_82.jpg
#   inflating: Clothing/T-Shirt/Image_996.jpg
#   inflating: Clothing/T-Shirt/Image_215.jpg
#   inflating: Clothing/T-Shirt/Image_349.png
#   inflating: Clothing/T-Shirt/Image_230.jpg
#   inflating: Clothing/T-Shirt/Image_319.jpeg
#   inflating: Clothing/T-Shirt/Image_143.jpg
#   inflating: Clothing/T-Shirt/Image_217.png
#   inflating: Clothing/T-Shirt/Image_748.jpg
#   inflating: Clothing/T-Shirt/Image_222.jpeg
#   inflating: Clothing/T-Shirt/Image_685.jpeg
#   inflating: Clothing/T-Shirt/Image_416.png
#   inflating: Clothing/T-Shirt/Image_202.jpg
#   inflating: Clothing/T-Shirt/Image_927.jpg
#   inflating: Clothing/T-Shirt/Image_960.jpg
#   inflating: Clothing/T-Shirt/Image_754.jpg
#   inflating: Clothing/T-Shirt/Image_871.jpg
#   inflating: Clothing/T-Shirt/Image_477.jpg
#   inflating: Clothing/T-Shirt/Image_254.jpg
#   inflating: Clothing/T-Shirt/Image_755.jpg
#   inflating: Clothing/T-Shirt/Image_160.png
#   inflating: Clothing/T-Shirt/Image_216.jpeg
#   inflating: Clothing/T-Shirt/Image_148.jpeg
#   inflating: Clothing/T-Shirt/Image_526.jpg
#   inflating: Clothing/T-Shirt/Image_12.jpg
#   inflating: Clothing/T-Shirt/Image_80.jpg
#   inflating: Clothing/T-Shirt/Image_362.jpg
#   inflating: Clothing/T-Shirt/Image_785.png
#   inflating: Clothing/T-Shirt/Image_306.jpeg
#   inflating: Clothing/T-Shirt/Image_89.jpg
#   inflating: Clothing/T-Shirt/Image_63.jpeg
#   inflating: Clothing/T-Shirt/Image_833.jpeg
#   inflating: Clothing/T-Shirt/Image_478.jpg
#   inflating: Clothing/T-Shirt/Image_336.png
#   inflating: Clothing/T-Shirt/Image_953.jpg
#   inflating: Clothing/T-Shirt/Image_171.jpeg
#   inflating: Clothing/T-Shirt/Image_1011.jpg
#   inflating: Clothing/T-Shirt/Image_813.jpg
#   inflating: Clothing/T-Shirt/Image_705.jpg
#   inflating: Clothing/T-Shirt/Image_977.png
#   inflating: Clothing/T-Shirt/Image_505.jpg
#   inflating: Clothing/T-Shirt/Image_971.png
#   inflating: Clothing/T-Shirt/Image_1026.jpg
#   inflating: Clothing/T-Shirt/Image_286.jpg
#   inflating: Clothing/T-Shirt/Image_691.jpeg
#   inflating: Clothing/T-Shirt/Image_480.jpg
#   inflating: Clothing/T-Shirt/Image_1056.jpg
#   inflating: Clothing/T-Shirt/Image_714.jpeg
#   inflating: Clothing/T-Shirt/Image_184.jpg
#   inflating: Clothing/T-Shirt/Image_43.jpeg
#   inflating: Clothing/T-Shirt/Image_15.png
#   inflating: Clothing/T-Shirt/Image_77.png
#   inflating: Clothing/T-Shirt/Image_1024.jpg
#   inflating: Clothing/T-Shirt/Image_121.jpg
#   inflating: Clothing/T-Shirt/Image_668.png
#   inflating: Clothing/T-Shirt/Image_36.png
#   inflating: Clothing/T-Shirt/Image_1059.jpg
#   inflating: Clothing/T-Shirt/Image_925.jpg
#   inflating: Clothing/T-Shirt/Image_208.jpeg
#   inflating: Clothing/T-Shirt/Image_634.jpg
#   inflating: Clothing/T-Shirt/Image_370.jpg
#   inflating: Clothing/T-Shirt/Image_801.png
#   inflating: Clothing/T-Shirt/Image_270.jpg
#   inflating: Clothing/T-Shirt/Image_964.jpeg
#   inflating: Clothing/T-Shirt/Image_775.png
#   inflating: Clothing/T-Shirt/Image_597.jpeg
#   inflating: Clothing/T-Shirt/Image_589.jpg
#   inflating: Clothing/T-Shirt/Image_695.jpeg
#   inflating: Clothing/T-Shirt/Image_343.jpg
#   inflating: Clothing/T-Shirt/Image_551.jpeg
#   inflating: Clothing/T-Shirt/Image_811.jpg
#   inflating: Clothing/T-Shirt/Image_565.jpeg
#   inflating: Clothing/T-Shirt/Image_661.jpg
#   inflating: Clothing/T-Shirt/Image_864.jpg
#   inflating: Clothing/T-Shirt/Image_877.png
#   inflating: Clothing/T-Shirt/Image_187.png
#   inflating: Clothing/T-Shirt/Image_869.jpeg
#   inflating: Clothing/T-Shirt/Image_81.jpeg
#   inflating: Clothing/T-Shirt/Image_643.jpg
#   inflating: Clothing/T-Shirt/Image_283.jpeg
#   inflating: Clothing/T-Shirt/Image_34.jpg
#   inflating: Clothing/T-Shirt/Image_770.jpg
#   inflating: Clothing/T-Shirt/Image_941.png
#   inflating: Clothing/T-Shirt/Image_265.png
#   inflating: Clothing/T-Shirt/Image_906.jpg
#   inflating: Clothing/T-Shirt/Image_87.jpg
#   inflating: Clothing/T-Shirt/Image_537.jpg
#   inflating: Clothing/T-Shirt/Image_1040.jpg
#   inflating: Clothing/T-Shirt/Image_173.jpg
#   inflating: Clothing/T-Shirt/Image_406.jpg
#   inflating: Clothing/T-Shirt/Image_791.jpg
#   inflating: Clothing/T-Shirt/Image_393.jpg
#   inflating: Clothing/T-Shirt/Image_199.jpg
#   inflating: Clothing/T-Shirt/Image_854.jpg
#   inflating: Clothing/T-Shirt/Image_596.jpg
#   inflating: Clothing/T-Shirt/Image_401.jpg
#   inflating: Clothing/T-Shirt/Image_895.jpg
#   inflating: Clothing/T-Shirt/Image_751.png
#   inflating: Clothing/T-Shirt/Image_149.jpg
#   inflating: Clothing/T-Shirt/Image_129.jpg
#   inflating: Clothing/T-Shirt/Image_75.jpeg
#   inflating: Clothing/T-Shirt/Image_618.png
#   inflating: Clothing/T-Shirt/Image_76.jpg
#   inflating: Clothing/T-Shirt/Image_981.jpeg
#   inflating: Clothing/T-Shirt/Image_497.jpg
#   inflating: Clothing/T-Shirt/Image_1055.jpg
#   inflating: Clothing/T-Shirt/Image_380.jpg
#   inflating: Clothing/T-Shirt/Image_84.jpg
#   inflating: Clothing/T-Shirt/Image_311.jpg
#   inflating: Clothing/T-Shirt/Image_409.jpeg
#   inflating: Clothing/T-Shirt/Image_93.jpg
#   inflating: Clothing/T-Shirt/Image_105.png
#   inflating: Clothing/T-Shirt/Image_878.jpg
#   inflating: Clothing/T-Shirt/Image_929.jpg
#   inflating: Clothing/T-Shirt/Image_771.jpg
#   inflating: Clothing/T-Shirt/Image_904.jpg
#   inflating: Clothing/T-Shirt/Image_111.jpg
#   inflating: Clothing/T-Shirt/Image_1014.jpg
#   inflating: Clothing/T-Shirt/Image_67.jpg
#   inflating: Clothing/T-Shirt/Image_753.jpg
#   inflating: Clothing/T-Shirt/Image_809.jpg
#   inflating: Clothing/T-Shirt/Image_397.png
#   inflating: Clothing/T-Shirt/Image_642.jpg
#   inflating: Clothing/T-Shirt/Image_237.jpeg
#   inflating: Clothing/T-Shirt/Image_164.png
#   inflating: Clothing/T-Shirt/Image_247.png
#   inflating: Clothing/T-Shirt/Image_266.jpg
#   inflating: Clothing/T-Shirt/Image_987.jpeg
#   inflating: Clothing/T-Shirt/Image_757.png
#   inflating: Clothing/T-Shirt/Image_550.jpg
#   inflating: Clothing/T-Shirt/Image_4.jpg
#   inflating: Clothing/T-Shirt/Image_814.jpg
#   inflating: Clothing/T-Shirt/Image_446.jpg
#   inflating: Clothing/T-Shirt/Image_53.jpg
#   inflating: Clothing/T-Shirt/Image_388.jpg
#   inflating: Clothing/T-Shirt/Image_573.jpg
#   inflating: Clothing/T-Shirt/Image_543.jpg
#   inflating: Clothing/T-Shirt/Image_560.jpg
#   inflating: Clothing/T-Shirt/Image_962.jpg
#   inflating: Clothing/T-Shirt/Image_425.jpeg
#   inflating: Clothing/T-Shirt/Image_959.jpg
#   inflating: Clothing/T-Shirt/Image_626.jpg
#   inflating: Clothing/T-Shirt/Image_234.png
#   inflating: Clothing/T-Shirt/Image_462.jpg
#   inflating: Clothing/T-Shirt/Image_85.jpg
#   inflating: Clothing/T-Shirt/Image_158.jpg
#   inflating: Clothing/T-Shirt/Image_70.jpg
#   inflating: Clothing/T-Shirt/Image_99.png
#   inflating: Clothing/T-Shirt/Image_212.png
#   inflating: Clothing/T-Shirt/Image_316.png
#   inflating: Clothing/T-Shirt/Image_1023.jpg
#   inflating: Clothing/T-Shirt/Image_232.png
#   inflating: Clothing/T-Shirt/Image_984.jpg
#   inflating: Clothing/T-Shirt/Image_715.jpg
#   inflating: Clothing/T-Shirt/Image_737.jpg
#   inflating: Clothing/T-Shirt/Image_150.jpg
#   inflating: Clothing/T-Shirt/Image_90.jpg
#   inflating: Clothing/T-Shirt/Image_582.png
#   inflating: Clothing/T-Shirt/Image_398.jpg
#   inflating: Clothing/T-Shirt/Image_555.png
#   inflating: Clothing/T-Shirt/Image_660.jpg
#   inflating: Clothing/T-Shirt/Image_61.jpg
#   inflating: Clothing/T-Shirt/Image_130.png
#   inflating: Clothing/T-Shirt/Image_253.jpg
#   inflating: Clothing/T-Shirt/Image_790.jpg
#   inflating: Clothing/T-Shirt/Image_100.jpg
#   inflating: Clothing/T-Shirt/Image_174.jpg
#   inflating: Clothing/T-Shirt/Image_841.jpeg
#   inflating: Clothing/T-Shirt/Image_684.jpg
#   inflating: Clothing/T-Shirt/Image_852.jpg
#   inflating: Clothing/T-Shirt/Image_449.jpg
#   inflating: Clothing/T-Shirt/Image_840.jpg
#   inflating: Clothing/T-Shirt/Image_688.jpg
#   inflating: Clothing/T-Shirt/Image_233.jpg
#   inflating: Clothing/T-Shirt/Image_562.jpg
#   inflating: Clothing/T-Shirt/Image_699.jpg
#   inflating: Clothing/T-Shirt/Image_204.jpg
#   inflating: Clothing/T-Shirt/Image_114.jpg
#   inflating: Clothing/T-Shirt/Image_352.png
#   inflating: Clothing/T-Shirt/Image_842.jpg
#   inflating: Clothing/T-Shirt/Image_317.jpg
#   inflating: Clothing/T-Shirt/Image_307.png
#   inflating: Clothing/T-Shirt/Image_115.jpg
#   inflating: Clothing/T-Shirt/Image_873.jpg
#   inflating: Clothing/T-Shirt/Image_492.jpg
#   inflating: Clothing/T-Shirt/Image_570.jpg
#   inflating: Clothing/T-Shirt/Image_914.jpg
#   inflating: Clothing/T-Shirt/Image_866.jpeg
#   inflating: Clothing/T-Shirt/Image_955.jpeg
#   inflating: Clothing/T-Shirt/Image_281.jpg
#   inflating: Clothing/T-Shirt/Image_1035.jpg
#   inflating: Clothing/T-Shirt/Image_334.jpg
#   inflating: Clothing/T-Shirt/Image_455.jpg
#   inflating: Clothing/T-Shirt/Image_533.jpg
#   inflating: Clothing/T-Shirt/Image_937.jpg
#   inflating: Clothing/T-Shirt/Image_186.jpg
#   inflating: Clothing/T-Shirt/Image_735.jpg
#   inflating: Clothing/T-Shirt/Image_260.jpg
#   inflating: Clothing/T-Shirt/Image_664.png
#   inflating: Clothing/T-Shirt/Image_595.jpg
#   inflating: Clothing/T-Shirt/Image_876.jpg
#   inflating: Clothing/T-Shirt/Image_653.jpg
#   inflating: Clothing/T-Shirt/Image_848.jpeg
#   inflating: Clothing/T-Shirt/Image_287.jpg
#   inflating: Clothing/T-Shirt/Image_807.jpg
#   inflating: Clothing/T-Shirt/Image_517.jpg
#   inflating: Clothing/T-Shirt/Image_74.jpeg
#   inflating: Clothing/T-Shirt/Image_305.jpg
#   inflating: Clothing/T-Shirt/Image_827.jpg
#   inflating: Clothing/T-Shirt/Image_145.jpg
#   inflating: Clothing/T-Shirt/Image_47.jpg
#   inflating: Clothing/T-Shirt/Image_465.jpg
#   inflating: Clothing/T-Shirt/Image_399.jpg
#   inflating: Clothing/T-Shirt/Image_487.jpg
#   inflating: Clothing/T-Shirt/Image_1045.jpg
#   inflating: Clothing/T-Shirt/Image_940.jpg
#   inflating: Clothing/T-Shirt/Image_556.png
#   inflating: Clothing/T-Shirt/Image_762.jpg
#   inflating: Clothing/T-Shirt/Image_384.jpg
#   inflating: Clothing/T-Shirt/Image_56.jpg
#   inflating: Clothing/T-Shirt/Image_269.jpg
#   inflating: Clothing/T-Shirt/Image_845.jpg
#   inflating: Clothing/T-Shirt/Image_671.jpg
#   inflating: Clothing/T-Shirt/Image_522.jpeg
#   inflating: Clothing/T-Shirt/Image_177.jpg
#   inflating: Clothing/T-Shirt/Image_985.jpeg
#   inflating: Clothing/T-Shirt/Image_141.jpg
#   inflating: Clothing/T-Shirt/Image_766.jpg
#   inflating: Clothing/T-Shirt/Image_739.jpeg
#   inflating: Clothing/T-Shirt/Image_151.jpg
#   inflating: Clothing/T-Shirt/Image_64.png
#   inflating: Clothing/T-Shirt/Image_142.jpg
#   inflating: Clothing/T-Shirt/Image_463.jpg
#   inflating: Clothing/T-Shirt/Image_30.jpeg
#   inflating: Clothing/T-Shirt/Image_321.jpg
#   inflating: Clothing/T-Shirt/Image_525.png
#   inflating: Clothing/T-Shirt/Image_335.jpg
#   inflating: Clothing/T-Shirt/Image_318.jpeg
#   inflating: Clothing/T-Shirt/Image_136.jpg
#   inflating: Clothing/T-Shirt/Image_804.jpg
#   inflating: Clothing/T-Shirt/Image_991.jpg
#   inflating: Clothing/T-Shirt/Image_400.jpg
#   inflating: Clothing/T-Shirt/Image_252.png
#   inflating: Clothing/T-Shirt/Image_1061.jpg
#   inflating: Clothing/T-Shirt/Image_758.jpg
#   inflating: Clothing/T-Shirt/Image_617.jpg
#   inflating: Clothing/T-Shirt/Image_1050.jpeg
#   inflating: Clothing/T-Shirt/Image_721.jpg
#   inflating: Clothing/T-Shirt/Image_161.png
#   inflating: Clothing/T-Shirt/Image_726.jpeg
#   inflating: Clothing/T-Shirt/Image_1019.jpg
#   inflating: Clothing/T-Shirt/Image_392.jpeg
#   inflating: Clothing/T-Shirt/Image_119.jpg
#   inflating: Clothing/T-Shirt/Image_367.jpg
#   inflating: Clothing/T-Shirt/Image_502.jpg
#   inflating: Clothing/T-Shirt/Image_919.jpg
#   inflating: Clothing/T-Shirt/Image_704.png
#   inflating: Clothing/T-Shirt/Image_568.jpg
#   inflating: Clothing/T-Shirt/Image_453.jpeg
#   inflating: Clothing/T-Shirt/Image_498.jpeg
#   inflating: Clothing/T-Shirt/Image_968.jpeg
#   inflating: Clothing/T-Shirt/Image_835.jpg
#   inflating: Clothing/T-Shirt/Image_62.jpg
#   inflating: Clothing/T-Shirt/Image_687.jpeg
#   inflating: Clothing/T-Shirt/Image_624.jpg
#   inflating: Clothing/T-Shirt/Image_563.png
#   inflating: Clothing/T-Shirt/Image_780.jpg
#   inflating: Clothing/T-Shirt/Image_774.jpg
#   inflating: Clothing/T-Shirt/Image_629.gif
#   inflating: Clothing/T-Shirt/Image_116.jpg
#   inflating: Clothing/T-Shirt/Image_513.png
#   inflating: Clothing/T-Shirt/Image_128.jpg
#   inflating: Clothing/T-Shirt/Image_553.jpg
#   inflating: Clothing/T-Shirt/Image_69.png
#   inflating: Clothing/T-Shirt/Image_239.jpg
#   inflating: Clothing/T-Shirt/Image_545.jpg
#   inflating: Clothing/T-Shirt/Image_167.jpeg
#   inflating: Clothing/T-Shirt/Image_22.jpg
#   inflating: Clothing/T-Shirt/Image_815.png
#   inflating: Clothing/T-Shirt/Image_25.jpeg
#   inflating: Clothing/T-Shirt/Image_1032.jpeg
#   inflating: Clothing/T-Shirt/Image_859.jpg
#   inflating: Clothing/T-Shirt/Image_443.jpeg
#   inflating: Clothing/T-Shirt/Image_694.jpg
#   inflating: Clothing/T-Shirt/Image_365.jpg
#   inflating: Clothing/T-Shirt/Image_299.png
#   inflating: Clothing/T-Shirt/Image_579.jpg
#   inflating: Clothing/T-Shirt/Image_686.jpg
#   inflating: Clothing/T-Shirt/Image_659.jpg
#   inflating: Clothing/T-Shirt/Image_118.png
#   inflating: Clothing/T-Shirt/Image_1054.jpg
#   inflating: Clothing/T-Shirt/Image_277.png
#   inflating: Clothing/T-Shirt/Image_667.jpeg
#   inflating: Clothing/T-Shirt/Image_320.jpg
#   inflating: Clothing/T-Shirt/Image_920.jpeg
#   inflating: Clothing/T-Shirt/Image_122.jpg
#   inflating: Clothing/T-Shirt/Image_945.jpg
#   inflating: Clothing/T-Shirt/Image_481.jpg
#   inflating: Clothing/T-Shirt/Image_364.JPG
#   inflating: Clothing/T-Shirt/Image_456.jpg
#   inflating: Clothing/T-Shirt/Image_410.jpg
#   inflating: Clothing/T-Shirt/Image_339.jpg
#   inflating: Clothing/T-Shirt/Image_274.png
#   inflating: Clothing/T-Shirt/Image_71.jpeg
#   inflating: Clothing/T-Shirt/Image_8.jpeg
#   inflating: Clothing/T-Shirt/Image_572.jpg
#   inflating: Clothing/T-Shirt/Image_988.jpg
#   inflating: Clothing/T-Shirt/Image_447.jpg
#   inflating: Clothing/T-Shirt/Image_767.jpg
#   inflating: Clothing/T-Shirt/Image_426.jpg
#   inflating: Clothing/T-Shirt/Image_108.png
#   inflating: Clothing/T-Shirt/Image_241.jpg
#   inflating: Clothing/T-Shirt/Image_156.jpg
#   inflating: Clothing/T-Shirt/Image_951.jpg
#   inflating: Clothing/T-Shirt/Image_855.jpg
#   inflating: Clothing/T-Shirt/Image_954.jpg
#   inflating: Clothing/T-Shirt/Image_332.jpg
#   inflating: Clothing/T-Shirt/Image_986.jpg
#   inflating: Clothing/T-Shirt/Image_574.jpg
#   inflating: Clothing/T-Shirt/Image_756.jpg
#   inflating: Clothing/T-Shirt/Image_810.jpeg
#   inflating: Clothing/T-Shirt/Image_716.jpg
#   inflating: Clothing/T-Shirt/Image_997.jpg
#   inflating: Clothing/T-Shirt/Image_1012.jpg
#   inflating: Clothing/T-Shirt/Image_201.jpg
#   inflating: Clothing/T-Shirt/Image_609.jpg
#   inflating: Clothing/T-Shirt/Image_961.jpeg
#   inflating: Clothing/T-Shirt/Image_939.jpg
#   inflating: Clothing/T-Shirt/Image_206.jpg
#   inflating: Clothing/T-Shirt/Image_92.png
#   inflating: Clothing/T-Shirt/Image_948.jpg
#   inflating: Clothing/T-Shirt/Image_196.png
#   inflating: Clothing/T-Shirt/Image_747.jpg
#   inflating: Clothing/T-Shirt/Image_863.jpg
#   inflating: Clothing/T-Shirt/Image_818.jpeg

# %%
import os
from PIL import Image

# Paths to the Soda Drinks directories
T_shirts_dir = '/content/drive/MyDrive/extracted_data/Clothing/T-Shirt'
Pants_dir = '/content/drive/MyDrive/extracted_data/Clothing/Pants'
others_dir = '/content/drive/MyDrive/extracted_data/Clothing/others'



# Initialize variables to store information
file_extensions = {'T-Shirt': [], 'Pants': [], 'others':[]}
image_shapes = {'T-Shirt': [], 'Pants': [], 'others':[]}
image_sizes = {'T-Shirt': [], 'Pants': [], 'others':[]}

# Function to explore images in a directory
def explore_images(directory, label):
    for filename in os.listdir(directory):
        file_path = os.path.join(directory, filename)
        try:
            with Image.open(file_path) as img:
                # Get file extension
                ext = filename.split('.')[-1].lower()
                file_extensions[label].append(ext)

                # Get image shape
                shape = img.size  # (width, height)
                image_shapes[label].append(shape)

                # Get image size in bytes
                size = os.path.getsize(file_path)
                image_sizes[label].append(size)
        except Exception as e:
            print(f"Could not process file {file_path}: {e}")

# Explore T-Shirt images
explore_images(T_shirts_dir, 'T-Shirt')
explore_images(Pants_dir, 'Pants')


# Display the results
print(f"T-Shirt Image Extensions: {set(file_extensions['T-Shirt'])}")
print(f"Pants Image Extensions: {set(file_extensions['Pants'])}")
print(f"others Image Extensions: {set(file_extensions['others'])}")

print(f"T-Shirt Image Shapes: {set(image_shapes['T-Shirt'])}")
print(f"Pants Image Shapes: {set(image_shapes['Pants'])}")
print(f"others Image Shapes: {set(image_shapes['others'])}")


print(f"T-Shirt Image Sizes (min, max): {min(image_sizes['T-Shirt'])} bytes, {max(image_sizes['T-Shirt'])} bytes")
print(f"Pants Image Sizes (min, max): {min(image_sizes['Pants'])} bytes, {max(image_sizes['Pants'])} bytes")
# Out:
# T-Shirt Image Extensions: {'jpeg', 'png', 'bmp', 'jpg', 'webp', 'gif'}
# Pants Image Extensions: {'png', 'jpeg', 'jpg'}
# others Image Extensions: set()
# T-Shirt Image Shapes: {(1200, 1600), (2048, 2731), (1500, 967), (1920, 1261), (500, 700), (580, 580), (1200, 1200), (236, 370), (1200, 800), (1655, 1591), (1339, 1800), (1100, 1100), (1920, 1117), (300, 400), (1798, 2332), (2640, 4048), (1760, 2040), (2511, 3000), (520, 650), (2083, 2083), (1800, 2140), (1500, 2000), (1600, 1050), (638, 800), (800, 960), (476, 500), (1920, 1229), (945, 960), (626, 417), (1130, 1500), (1053, 768), (1000, 1390), (1500, 1200), (735, 836), (235, 293), (1198, 1500), (600, 800), (1000, 999), (1010, 1458), (1024, 1365), (900, 1195), (3000, 2000), (768, 1152), (1200, 1801), (1920, 1224), (1536, 1536), (1920, 1080), (1000, 985), (1536, 2048), (564, 720), (1600, 1157), (790, 1184), (3080, 3300), (660, 535), (1000, 1250), (1472, 980), (1740, 1158), (1128, 1692), (672, 1412), (736, 920), (1004, 1000), (1046, 1500), (804, 804), (1400, 829), (728, 1092), (1400, 1750), (1242, 1560), (1200, 1176), (1199, 1208), (1140, 1140), (1040, 1300), (1600, 1161), (971, 1200), (736, 897), (1900, 2850), (902, 957), (1170, 1674), (563, 844), (1920, 976), (1200, 1800), (637, 640), (873, 1024), (735, 565), (1000, 1137), (236, 314), (3588, 5381), (239, 239), (1500, 1441), (1400, 1592), (1331, 1331), (1224, 1632), (927, 1000), (2000, 2667), (2611, 2564), (1714, 2560), (1125, 1500), (1590, 1200), (2457, 3000), (1080, 720), (570, 725), (1246, 1246), (640, 960), (629, 640), (3024, 4032), (1500, 1418), (1155, 1500), (3000, 3000), (1339, 1339), (600, 600), (2050, 2263), (1280, 1280), (3000, 1962), (2000, 2500), (1091, 1600), (1000, 1500), (1600, 1236), (1680, 2400), (615, 615), (500, 387), (531, 640), (918, 918), (2387, 2387), (1200, 1799), (236, 295), (405, 500), (652, 1024), (1800, 1800), (1024, 1313), (1797, 980), (640, 640), (1440, 1920), (700, 700), (893, 1113), (1574, 1600), (792, 792), (853, 640), (400, 533), (1000, 1333), (420, 529), (1100, 1200), (1920, 1037), (728, 910), (800, 786), (220, 220), (828, 1104), (683, 1024), (1900, 1900), (1236, 1600), (3262, 3261), (609, 684), (3005, 3437), (700, 951), (922, 1162), (1814, 1814), (1450, 2175), (900, 994), (933, 1000), (1431, 868), (1372, 980), (736, 980), (768, 960), (455, 500), (662, 960), (1500, 1403), (1756, 1756), (1900, 2533), (446, 280), (1320, 1320), (1024, 894), (830, 1038), (741, 960), (1333, 1500), (147, 221), (1600, 956), (736, 1101), (1200, 2148), (870, 1110), (735, 913), (2000, 2732), (1500, 1524), (1633, 980), (1024, 768), (400, 532), (2000, 1200), (1470, 980), (1000, 667), (1024, 1024), (1073, 1164), (2608, 3005), (590, 939), (236, 289), (1792, 1534), (177, 221), (1024, 1536), (466, 580), (1800, 2041), (470, 470), (2250, 3000), (400, 500), (679, 836), (750, 1125), (539, 960), (533, 800), (236, 257), (1000, 1318), (1300, 1430), (655, 655), (468, 280), (481, 600), (800, 1000), (414, 556), (1920, 1278), (1200, 970), (794, 935), (445, 543), (720, 720), (1000, 1192), (800, 600), (679, 975), (1440, 1729), (736, 691), (1920, 1152), (1820, 1214), (1500, 1999), (1405, 1600), (901, 1200), (1080, 1440), (1600, 1067), (1920, 1920), (2316, 3061), (218, 221), (800, 833), (474, 592), (2181, 3272), (640, 853), (736, 839), (1461, 1500), (2400, 3078), (1150, 1360), (1200, 812), (344, 482), (461, 500), (6493, 8000), (1500, 1500), (1888, 2000), (736, 1104), (1890, 2836), (1575, 1360), (570, 672), (1920, 1156), (1200, 1086), (831, 960), (1500, 700), (1280, 1600), (2000, 3000), (1331, 1920), (1080, 1920), (3200, 1800), (626, 447), (1600, 900), (3000, 2794), (993, 1390), (354, 500), (1920, 1371), (736, 681), (1400, 1893), (1920, 1142), (900, 1198), (2518, 2000), (2000, 1000), (1024, 577), (1365, 2048), (819, 819), (4000, 4607), (1153, 1500), (1347, 2021), (1814, 980), (1563, 980), (1200, 1840), (564, 705), (1331, 1524), (218, 220), (550, 550), (2008, 1223), (3648, 5472), (1840, 2560), (1920, 1357), (734, 734), (1551, 2048), (794, 794), (600, 901), (960, 1500), (2490, 1667), (794, 1059), (1700, 2549), (1000, 1792), (800, 1200), (500, 450), (768, 768), (800, 800), (1000, 1410), (1504, 7 ...
# Pants Image Shapes: {(836, 1049), (1200, 1600), (2048, 2731), (357, 633), (580, 580), (966, 1024), (1200, 1200), (1100, 1500), (750, 1000), (1653, 2494), (1588, 1821), (1206, 862), (1200, 800), (1100, 1100), (300, 400), (1760, 2040), (1140, 1429), (1500, 2400), (900, 1200), (520, 650), (1500, 2000), (994, 1500), (2560, 4708), (683, 1598), (1200, 674), (1424, 2136), (450, 600), (2822, 4884), (1050, 1400), (800, 1463), (1000, 752), (600, 800), (3619, 5429), (1024, 1365), (665, 865), (1000, 1282), (2304, 3456), (1425, 1425), (768, 1152), (1000, 2203), (250, 250), (1536, 1536), (1920, 2563), (1138, 1755), (1250, 1667), (2560, 4995), (690, 1070), (1920, 1080), (741, 743), (830, 830), (808, 1080), (2400, 2400), (1320, 2024), (891, 1334), (979, 800), (1904, 3481), (736, 920), (1620, 1080), (970, 1245), (1673, 1918), (1140, 1140), (1040, 1300), (2048, 1678), (676, 1014), (1959, 2500), (666, 1000), (1571, 2000), (2624, 3936), (63, 140), (964, 1444), (1440, 1800), (682, 1200), (1200, 1800), (564, 845), (1000, 1137), (1200, 1400), (446, 291), (1800, 2475), (1224, 1632), (490, 733), (2000, 2667), (1125, 1500), (1563, 2000), (1019, 1384), (680, 1024), (340, 510), (900, 600), (640, 960), (224, 335), (2472, 3528), (3024, 4032), (1287, 1930), (1067, 1280), (3173, 4231), (1400, 2243), (3000, 3000), (400, 426), (972, 1137), (665, 998), (600, 600), (375, 500), (1920, 2880), (1280, 1280), (600, 856), (2000, 2500), (1280, 1536), (2000, 2509), (1000, 1500), (240, 320), (1600, 1919), (1290, 1693), (1380, 1986), (830, 1601), (738, 960), (1200, 1799), (700, 817), (1800, 1800), (1400, 1820), (1281, 1500), (640, 640), (941, 1800), (2000, 2666), (800, 400), (700, 700), (955, 1991), (2560, 4651), (660, 1000), (1500, 1125), (1706, 2560), (536, 960), (923, 1095), (798, 1500), (2380, 4832), (1023, 1200), (2240, 3360), (683, 1024), (1900, 1900), (2010, 3590), (1020, 1530), (746, 900), (460, 552), (212, 212), (751, 1024), (800, 1127), (1280, 2438), (819, 1024), (736, 980), (360, 482), (3073, 4031), (964, 1280), (1000, 1602), (272, 500), (391, 600), (228, 304), (870, 1110), (2560, 4888), (736, 1128), (1024, 768), (360, 468), (1000, 667), (3988, 3988), (1024, 1024), (2608, 3005), (1024, 1280), (250, 300), (1382, 1766), (1536, 1604), (1800, 2297), (733, 1100), (2250, 3000), (400, 500), (693, 1000), (600, 683), (1000, 1300), (1800, 2400), (4272, 2848), (2000, 3001), (2400, 3200), (470, 600), (1150, 1500), (1200, 1846), (624, 676), (720, 720), (460, 690), (800, 600), (2308, 3000), (1000, 1286), (301, 400), (482, 960), (1000, 895), (1080, 1440), (1231, 1600), (513, 655), (1140, 655), (1024, 1279), (598, 1000), (1340, 2010), (998, 998), (228, 262), (850, 1090), (2181, 3272), (701, 720), (1500, 1500), (736, 1104), (1500, 844), (2400, 2925), (147, 300), (750, 1124), (949, 1095), (1500, 2250), (1800, 2399), (1280, 1600), (2000, 3000), (684, 1026), (3464, 4619), (1599, 1600), (650, 813), (2048, 2329), (1152, 1536), (1760, 2200), (1200, 816), (474, 1090), (1500, 1980), (1230, 1500), (635, 635), (1023, 1534), (440, 404), (1677, 1923), (1440, 1440), (1000, 750), (980, 1446), (1800, 2268), (550, 550), (1829, 2560), (734, 734), (970, 992), (794, 794), (576, 553), (800, 1200), (757, 1000), (1400, 2000), (780, 1389), (768, 768), (800, 800), (960, 1365), (2048, 2328), (624, 723), (1125, 1688), (840, 1147), (2000, 1125), (1750, 2500), (1000, 1019), (600, 923), (1230, 1575), (1500, 2100), (228, 242), (472, 630), (2600, 2400), (900, 900), (833, 999), (1466, 2480), (628, 450), (960, 960), (570, 854), (720, 960), (484, 860), (1200, 630), (600, 900), (1129, 1500), (1179, 1766), (1200, 1560), (267, 300), (875, 875), (800, 1199), (1732, 2500), (739, 960), (1117, 1400), (4000, 5333), (228, 228), (829, 1500), (1000, 1400), (2000, 2000), (1600, 2048), (1000, 1000), (570, 858), (780, 826), (740, 1180), (569, 1298), (2048, 1365), (833, 1600), (721, 1041), (1969, 2560), (2048, 2048), (1242, 1795), (1186, 848), (729, 1408), (662, 1000), (1280, 2343), (1125, 1902), (2048, 2560), (353, 748), (19 ...
# others Image Shapes: set()
# T-Shirt Image Sizes (min, max): 3127 bytes, 3521829 bytes
# Pants Image Sizes (min, max): 2478 bytes, 7918274 bytes

# %%
# Count the number of images in each class
num_T_Shirt_images = len(os.listdir(T_shirts_dir))
num_Pants_images = len(os.listdir(Pants_dir))
num_others_images = len(os.listdir(others_dir))

# Print the results
num_T_Shirt_images, num_Pants_images, num_others_images
# Out:
# (1063, 1001, 2052)

# %%
import torch
from torch import nn, optim
from torchvision import datasets, transforms, models
from torch.utils.data import DataLoader, random_split
from sklearn.metrics import classification_report, confusion_matrix
import os
from PIL import Image

# Define dataset path
data_dir = '/content/drive/MyDrive/extracted_data/Clothing'


def convert_to_rgb(image):
    """
    Converts 'P' mode images with transparency to 'RGBA', and then to 'RGB'.
    This is to avoid transparency issues during model training.
    """
    if image.mode in ('P', 'RGBA'):
        return image.convert('RGB')
    return image

# Update the transformations for both training and validation
train_transform = transforms.Compose([
    transforms.Lambda(convert_to_rgb),  # Convert to RGB
    transforms.Resize((224, 224)),      # Resize images to 224x224
    transforms.RandomHorizontalFlip(),  # Augmentation: randomly flip images
    transforms.ToTensor(),              # Convert to tensor
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])  # Normalize with ImageNet mean and std
])

val_transform = transforms.Compose([
    transforms.Lambda(convert_to_rgb),  # Convert to RGB
    transforms.Resize((224, 224)),      # Resize images to 224x224
    transforms.ToTensor(),              # Convert to tensor
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])  # Normalize with ImageNet mean and std
])


# Load dataset with ImageFolder
dataset = datasets.ImageFolder(root=data_dir, transform=train_transform)

# %%
# Split dataset into training (80%) and validation (20%)
train_size = int(0.8 * len(dataset))
val_size = len(dataset) - train_size
train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

# Apply validation transforms to validation set
val_dataset.dataset.transform = val_transform

# Create DataLoader for training and validation sets
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)

# %%
# Load a pre-trained ResNet model
model = models.resnet18(pretrained=True)
model
# Out:
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet18_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet18_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# ResNet(
#   (conv1): Conv2d(3, 64, kernel_size=(7, 7), stride=(2, 2), padding=(3, 3), bias=False)
#   (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (relu): ReLU(inplace=True)
#   (maxpool): MaxPool2d(kernel_size=3, stride=2, padding=1, dilation=1, ceil_mode=False)
#   (layer1): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(64, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer2): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(64, 128, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(128, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer3): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(128, 256, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(128, 256, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (layer4): Sequential(
#     (0): BasicBlock(
#       (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (downsample): Sequential(
#         (0): Conv2d(256, 512, kernel_size=(1, 1), stride=(2, 2), bias=False)
#         (1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       )
#     )
#     (1): BasicBlock(
#       (conv1): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn1): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#       (relu): ReLU(inplace=True)
#       (conv2): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1), bias=False)
#       (bn2): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     )
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(1, 1))
#   (fc): Linear(in_features=512, out_features=1000, bias=True)
# )

# %%
# Modify the last layer to match the number of classes (2 classes: pants, T-shirt)
model.fc = nn.Linear(512, 3)  # 3 classes

# Move model to GPU if available
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
model = model.to(device)

# Define loss function and optimizer
criterion = nn.CrossEntropyLoss()
optimizer = optim.Adam(model.parameters(), lr=0.001)

# %%
# Training and validation loop
epochs = 10
best_val_acc = 0.0

for epoch in range(epochs):
    print(f"Epoch {epoch+1}/{epochs}")

    # Training phase
    model.train()
    running_loss = 0.0
    running_corrects = 0

    for inputs, labels in train_loader:
        inputs, labels = inputs.to(device), labels.to(device)

        # Zero the parameter gradients
        optimizer.zero_grad()

        # Forward pass
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)
        loss = criterion(outputs, labels)

        # Backward pass and optimization
        loss.backward()
        optimizer.step()

        # Track loss and accuracy
        running_loss += loss.item() * inputs.size(0)
        running_corrects += torch.sum(preds == labels.data)

    epoch_loss = running_loss / len(train_dataset)
    epoch_acc = running_corrects.double() / len(train_dataset)

    print(f"Train Loss: {epoch_loss:.4f} Acc: {epoch_acc:.4f}")

    # Validation phase
    model.eval()
    val_loss = 0.0
    val_corrects = 0
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for inputs, labels in val_loader:
            inputs, labels = inputs.to(device), labels.to(device)

            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            loss = criterion(outputs, labels)

            val_loss += loss.item() * inputs.size(0)
            val_corrects += torch.sum(preds == labels.data)

            # Store predictions and labels for metrics
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    val_loss = val_loss / len(val_dataset)
    val_acc = val_corrects.double() / len(val_dataset)

    print(f"Val Loss: {val_loss:.4f} Acc: {val_acc:.4f}")

    # Precision, Recall, F1-Score
    print("\nClassification Report:")
    print(classification_report(all_labels, all_preds, target_names=dataset.classes))

    # Save the best model
    if val_acc > best_val_acc:
        best_val_acc = val_acc
        torch.save(model.state_dict(), 'best_model.pth')

print(f'Best Validation Accuracy: {best_val_acc:.4f}')
# Out:
# Epoch 1/10
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py:1056: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Train Loss: 0.3448 Acc: 0.8614
# Val Loss: 0.1972 Acc: 0.9208
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        Pants       0.93      0.96      0.94       183
#      T-Shirt       0.88      0.88      0.88       206
#       others       0.93      0.92      0.93       432
#
#     accuracy                           0.92       821
#    macro avg       0.92      0.92      0.92       821
# weighted avg       0.92      0.92      0.92       821
#
# Epoch 2/10
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py:1056: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Train Loss: 0.1482 Acc: 0.9445
# Val Loss: 0.1635 Acc: 0.9391
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        Pants       0.97      0.95      0.96       183
#      T-Shirt       0.92      0.90      0.91       206
#       others       0.93      0.95      0.94       432
#
#     accuracy                           0.94       821
#    macro avg       0.94      0.93      0.94       821
# weighted avg       0.94      0.94      0.94       821
#
# Epoch 3/10
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py:1056: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Train Loss: 0.0847 Acc: 0.9711
# Val Loss: 0.2288 Acc: 0.9086
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        Pants       0.80      0.97      0.88       183
#      T-Shirt       0.91      0.91      0.91       206
#       others       0.97      0.88      0.92       432
#
#     accuracy                           0.91       821
#    macro avg       0.89      0.92      0.90       821
# weighted avg       0.92      0.91      0.91       821
#
# Epoch 4/10
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py:1056: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Train Loss: 0.0959 Acc: 0.9668
# Val Loss: 0.2288 Acc: 0.9281
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        Pants       0.93      0.95      0.94       183
#      T-Shirt       0.88      0.93      0.91       206
#       others       0.95      0.92      0.94       432
#
#     accuracy                           0.93       821
#    macro avg       0.92      0.93      0.93       821
# weighted avg       0.93      0.93      0.93       821
#
# Epoch 5/10
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py:1056: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Train Loss: 0.0707 Acc: 0.9744
# Val Loss: 0.4363 Acc: 0.8794
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        Pants       0.99      0.74      0.85       183
#      T-Shirt       0.95      0.79      0.86       206
#       others       0.83      0.98      0.90       432
#
#     accuracy                           0.88       821
#    macro avg       0.92      0.84      0.87       821
# weighted avg       0.89      0.88      0.88       821
#
# Epoch 6/10
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py:1056: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Train Loss: 0.0307 Acc: 0.9878
# Val Loss: 0.3561 Acc: 0.8965
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        Pants       0.83      0.97      0.90       183
#      T-Shirt       0.86      0.91      0.88       206
#       others       0.95      0.86      0.90       432
#
#     accuracy                           0.90       821
#    macro avg       0.88      0.91      0.89       821
# weighted avg       0.90      0.90      0.90       821
#
# Epoch 7/10
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py:1056: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Train Loss: 0.0955 Acc: 0.9659
# Val Loss: 0.2155 Acc: 0.9415
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        Pants       0.96      0.94      0.95       183
#      T-Shirt       0.94      0.90      0.92       206
#       others       0.94      0.96      0.95       432
#
#     accuracy                           0.94       821
#    macro avg       0.94      0.93      0.94       821
# weighted avg       0.94      0.94      0.94       821
#
# Epoch 8/10
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py:1056: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Train Loss: 0.0555 Acc: 0.9817
# Val Loss: 0.2676 Acc: 0.9294
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        Pants       0.96      0.92      0.94       183
#      T-Shirt       0.92      0.89      0.91       206
#       others       0.92      0.95      0.94       432
#
#     accuracy                           0.93       821
#    macro avg       0.93      0.92      0.93       821
# weighted avg       0.93      0.93      0.93       821
#
# Epoch 9/10
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py:1056: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Train Loss: 0.0331 Acc: 0.9881
# Val Loss: 0.2549 Acc: 0.9440
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        Pants       0.97      0.95      0.96       183
#      T-Shirt       0.90      0.95      0.92       206
#       others       0.96      0.94      0.95       432
#
#     accuracy                           0.94       821
#    macro avg       0.94      0.95      0.94       821
# weighted avg       0.94      0.94      0.94       821
#
# Epoch 10/10
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py:1056: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(
# Train Loss: 0.0192 Acc: 0.9930
# Val Loss: 0.2293 Acc: 0.9428
#
# Classification Report:
#               precision    recall  f1-score   support
#
#        Pants       0.91      0.97      0.94       183
#      T-Shirt       0.93      0.95      0.94       206
#       others       0.97      0.93      0.95       432
#
#     accuracy                           0.94       821
#    macro avg       0.93      0.95      0.94       821
# weighted avg       0.94      0.94      0.94       821
#
# Best Validation Accuracy: 0.9440

# %%
import shutil

# Define source and destination paths
source_path = '/content/best_model.pth'
destination_path = '/content/drive/MyDrive/data/Final Project /Clothes_best_model.pth'

# Copy the file
shutil.copy(source_path, destination_path)

print(f'File copied from {source_path} to {destination_path}')
# Out:
# File copied from /content/best_model.pth to /content/drive/MyDrive/data/Final Project /Clothes_best_model.pth

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch

# Function to display image along with the title
def imshow(image, title=None):
    """Display an image tensor."""
    # Undo the normalization (reverse mean and std)
    image = image.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    image = np.clip(image, 0, 1)  # Ensure values are between 0 and 1
    plt.imshow(image)
    if title:
        plt.title(title)
    plt.axis('off')  # Hide axis
    plt.pause(0.001)  # Pause for a short time so the plot updates

# Function to show random images along with true and predicted labels
def show_random_prediction():
    model.eval()  # Set the model to evaluation mode

    # Load one random batch from validation data
    inputs, labels = next(iter(val_loader))
    inputs, labels = inputs.to(device), labels.to(device)

    # Get model predictions
    with torch.no_grad():
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)

    # Move inputs, labels, and predictions back to CPU for visualization
    inputs = inputs.cpu()
    labels = labels.cpu()
    preds = preds.cpu()

    # Display multiple images along with their predictions
    plt.figure(figsize=(12, 12))

    # Show 6 random images from the batch
    for i in range(6):  # Showing 6 images
        rand_idx = np.random.randint(0, len(inputs))  # Pick a random index

        plt.subplot(2, 3, i+1)  # Create a 2x3 grid of images

        imshow(inputs[rand_idx],
               title=f"True: {dataset.classes[labels[rand_idx]]}\nPredicted: {dataset.classes[preds[rand_idx]]}")

    plt.show()

# Call the function to show random predictions
show_random_prediction()
# Out:
# /usr/local/lib/python3.10/dist-packages/PIL/Image.py:1056: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   warnings.warn(

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# # code to use saving model
# model = models.resnet18(pretrained=False)
# num_ftrs = model.fc.in_features
# model.fc = nn.Linear(num_ftrs, 2)  # 2 classes
# model.load_state_dict(torch.load('/content/best_model.pth'))
# model = model.to(device)

# %%
import matplotlib.pyplot as plt
import numpy as np
import torch

# Function to display image along with the title
def imshow(image, title=None):
    """Display an image tensor."""
    # Undo the normalization (reverse mean and std)
    image = image.numpy().transpose((1, 2, 0))
    mean = np.array([0.485, 0.456, 0.406])
    std = np.array([0.229, 0.224, 0.225])
    image = std * image + mean
    image = np.clip(image, 0, 1)  # Ensure values are between 0 and 1
    plt.imshow(image)
    if title:
        plt.title(title)
    plt.axis('off')  # Hide axis
    plt.pause(0.001)  # Pause for a short time so the plot updates

# Function to show random images along with true and predicted labels
def show_random_prediction():
    model.eval()  # Set the model to evaluation mode

    # Load one random batch from validation data
    inputs, labels = next(iter(val_loader))
    inputs, labels = inputs.to(device), labels.to(device)

    # Get model predictions
    with torch.no_grad():
        outputs = model(inputs)
        _, preds = torch.max(outputs, 1)

    # Move inputs, labels, and predictions back to CPU for visualization
    inputs = inputs.cpu()
    labels = labels.cpu()
    preds = preds.cpu()

    # Display multiple images along with their predictions
    plt.figure(figsize=(12, 12))

    # Show 6 random images from the batch
    for i in range(6):  # Showing 6 images
        rand_idx = np.random.randint(0, len(inputs))  # Pick a random index

        plt.subplot(2, 3, i+1)  # Create a 2x3 grid of images

        imshow(inputs[rand_idx],
               title=f"True: {dataset.classes[labels[rand_idx]]}\nPredicted: {dataset.classes[preds[rand_idx]]}")

    plt.show()

# Call the function to show random predictions
show_random_prediction()
